# %% [markdown]
# <a href="https://colab.research.google.com/github/DimasNDP/PCVK_Genap_2021/blob/master/Week2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

# Accessing My Google Drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np
img = cv.imread('/content/drive/MyDrive/santiago-bernabeu.jpg')
plt.imshow(img)

# %%
img2 = img
img3 = cv.cvtColor(img,cv.COLOR_BGR2RGB)    #Konversi channel BGR -> RGB
plt.imshow(img3)

# %%
#JAWABAN TUGAS NO 2

plt.imshow(img_gray, cmap='RdYlGn'),plt.title("Red-Green")
# Out:
# (<matplotlib.image.AxesImage at 0x7fca144b9f10>, Text(0.5, 1.0, 'Red-Green'))

# %%
plt.imshow(img_gray, cmap='GnBu'),plt.title("Green-Blue")
# Out:
# (<matplotlib.image.AxesImage at 0x7fca14567390>, Text(0.5, 1.0, 'Green-Blue'))

# %%
#JAWABAN TUGAS NO 3

croppedImg = img[20:250, 20:250]
plt.imshow(croppedImg)

# %%
#JAWABAN TUGAS NO 4

croppedImg = img[7:27, 0:0]

# %%
#JAWABAN TUGAS NO 5

# %%
img_gray = cv.imread('/content/drive/MyDrive/santiago-bernabeu.jpg', cv.IMREAD_GRAYSCALE)
plt.imshow(img_gray)

# %%
plt.imshow(img_gray, cmap='gray')

# %%
plt.imshow(img_gray, cmap='magma')

# %%
img4 = cv.resize(cv.cvtColor(img,cv.COLOR_BGR2RGB), (512,1024))
plt.imshow(img4)

# %%
img5 = cv.flip(cv.cvtColor(img,cv.COLOR_BGR2RGB),0)

#simpan File image
#cv.imwrite('/content/drive/MyDrive/santiago-bernabeu.jpg',img5)

#Tampilkan plot dengan ukuran canvas yang lebih besar
fig = plt.figure(figsize=(10,10))       #ubah-ubah ukuran (10,10) sesuai kebutuhan
ax = fig.add_subplot(111)
ax.imshow(img5)

# %%
black_img = np.zeros(shape=(512,512,3),dtype=np.int16)
plt.imshow(black_img)

# %%
#perhatikan koordiant titik2 pt1 dan pt2
cv.rectangle(black_img,pt1=(384,0),pt2=(510,150),color=(0,255,0),thickness=10)
plt.imshow(black_img)

# %%
cv.rectangle(black_img,pt1=(200,200),pt2=(300,300),color=(0,0,255),thickness=15)
plt.imshow(black_img)

# %%
cv.circle(black_img,center=(100,100),radius=50,color=(255,0,0),thickness=10)
plt.imshow(black_img)

# %%
cv.line(black_img,pt1=(0,0),pt2=(512,512),color=(255,255,255),thickness=5)
plt.imshow(black_img)

# %%
font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(black_img,text='Hello',org=(10,500),fontFace=font,fontScale=4,color=(255,255,0),thickness=2,lineType=cv.LINE_AA)
plt.imshow(black_img)

# %%
black_img2=np.zeros(shape=(512,512,3),dtype=np.int32)
plt.imshow(black_img2)

# %%
vertices = np.array([[100,300],[200,200],[400,300],[200,400]],dtype=np.int32)
vertices
# Out:
# array([[100, 300],
#        [200, 200],
#        [400, 300],
#        [200, 400]], dtype=int32)

# %%
pts = vertices.reshape((-1,1,2))    # nilai 2 untuk menunjukkan bahwa tiap titik dibuat 3 channel yg mewakili R, G, dan B
pts
# Out:
# array([[[100, 300]],
#
#        [[200, 200]],
#
#        [[400, 300]],
#
#        [[200, 400]]], dtype=int32)

# %%
cv.polylines(black_img2,[pts],isClosed=True,color=(255,0,0),thickness=5)
plt.imshow(black_img2)

# %%
#JAWABAN TUGAS 2 NO 1

# %%
#JAWABAN TUGAS 2 NO 2

# %%
#JAWABAN TUGAS 2 NO 3

# %% [markdown]
# Jawaban Pertanyaan
#
# 1. jika menampilkan gambar menggunakan matplotlib maka gambar akan tampil dengan ukuran dari gambar tersebut, sebaliknya jika tanpa matplotlib maka akan tampil gambar saja
# 2. Tidak berpengaruh untuk pembuatan black image
# 3. Menambahkan satu patches karena cv.imshow tidak berjalan di Google Colab
# 4. Untuk mengimpor modul io dari skimage (skimage.io) sehingga kita dapat membaca dan menulis gambar
