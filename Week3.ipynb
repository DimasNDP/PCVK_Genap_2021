# %% [markdown]
# <a href="https://colab.research.google.com/github/DimasNDP/PCVK_Genap_2021/blob/master/Week3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np
import math

# %%
print(' Mengubah tingkat kecerahan citra ')
print(' -------------------------------- ')

try:
    brightness = int(input('Masukan nilai kecerahan: '))
except ValueError:
    print('Error, not a number')

original = cv.imread('/content/drive/MyDrive/santiago-bernabeu.jpg')
brightness_image = np.zeros(original.shape, original.dtype)

for y in range(original.shape[0]):
    for x in range(original.shape[1]):
        for c in range(original.shape[2]):
            brightness_image[y,x,c] = np.clip(original[y,x,c] + brightness, 0, 255)

final_frame = cv.hconcat((original, brightness_image))
cv2_imshow(final_frame)
# Out:
#  Mengubah tingkat kecerahan citra
#  --------------------------------
# Masukan nilai kecerahan: 50
# <PIL.Image.Image image mode=RGB size=2400x630 at 0x7FD859D19CD0>

# %%
#Tugas Praktikum No. 1
print(' Mengubah kontras dan tingkat kecerahan citra ')
print(' -------------------------------- ')

try:
    brightness = int(input('Masukkan nilai kecerahan[-255 - 255]: '))
    contrast = float(input('Masukkan kontras [1.0 - 3.0]: '))
except ValueError:
    print('Error, not a number')

original = cv.imread('/content/drive/MyDrive/santiago-bernabeu.jpg')
contrast_image = np.zeros(original.shape, original.dtype)

for y in range(original.shape[0]):
    for x in range(original.shape[1]):
        for c in range(original.shape[2]):
            contrast_image[y,x,c] = np.clip(contrast*original[y,x,c] + brightness, 0, 255)

final_frame = cv.hconcat((original, contrast_image))
cv2_imshow(final_frame)
# Out:
#  Mengubah kontras dan tingkat kecerahan citra
#  --------------------------------
# Masukkan nilai kecerahan[-255 - 255]: 60
# Masukkan kontras [1.0 - 3.0]: 1.5
# <PIL.Image.Image image mode=RGB size=2400x630 at 0x7FD859478610>

# %%
#Tugas Praktikum No. 2

# %%
#Tugas Praktikum No. 3

#Averaging

img = cv.imread('/content/drive/MyDrive/santiago-bernabeu.jpg')
img_color = cv.cvtColor(img,cv.COLOR_BGR2RGB)

plt.imshow(img_color)
R, G, B = img_color[:,:,0], img_color[:,:,1],img_color[:,:,2]
gray_img = ( R + G + B) / 0.3

f, axarr = plt.subplots(1,2)
axarr[0].imshow(img_color)
axarr[1].imshow(gray_img, cmap='gray')

# %%
#Lightness

R, G, B = img_color[:,:,0], img_color[:,:,1], img_color[:,:,2]
max_channels = np.maximum(np.maximum(R, G), B)
min_channels = np.minimum(np.maximum(R, G), B)

gray_img = 0.5 * (max_channels + min_channels)

f, axarr = plt.subplots(1,2)
axarr[0].imshow(img_color)
axarr[1].imshow(gray_img, cmap='gray')

# %%
#Luminance

fix_img = cv.cvtColor(original, cv.COLOR_BGR2RGB)
plt.imshow(fix_img)

#Let's extract the three channels
R, G, B = fix_img[:,:,0], fix_img[:,:,1],fix_img[:,:,2]
Z = 0.2126 * R + 0.7152 * G + 0.0722 * B
print(Z)

plt.imshow(Z, cmap='gray')
plt.savefig('original')
# Out:
# [[ 24.3518  29.3518  33.3518 ...  25.8556  23.8556  22.8556]
#  [ 32.3518  32.3518  31.3518 ...  25.8556  24.8556  23.8556]
#  [ 38.9226  33.9226  28.9226 ...  28.8556  28.8556  28.8556]
#  ...
#  [193.3542 190.3542 184.3542 ... 206.3542 209.3542 211.3542]
#  [205.3542 205.3542 201.3542 ... 203.4264 204.4264 206.4264]
#  [212.3542 213.3542 212.3542 ... 201.4264 201.4264 202.4264]]

# %%
#Tugas Praktikum No. 4
